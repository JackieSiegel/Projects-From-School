# %%
#Observations
#There are significantly less drivers in rural areas
#The average fare in rural areas is higher becuase your destination would seem to be further away
#Suburban drivers make up 30% of the total fares by city type but only 26% of the rides
